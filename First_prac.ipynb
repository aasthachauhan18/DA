# %%
import numpy as np

arr = np.array([10,20,30,40])
print(arr.mean())
# Out:
# 25.0

# %%
import pandas as pd

data={"Marks":[70,80,90]}
df=pd.DataFrame(data)
print(df.mean())
# Out:
# Marks    80.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
marks=[60,70,80,90]
plt.plot(marks)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data={
    'Student':['A','B','C','D','E','F','G','H'],
    'Marks':[45,55,60,70,75,85,90,100],
    'Attendance':[60,65,70,75,80,85,90,95]
}
df = pd.DataFrame(data)
df
# Out:
#   Student  Marks  Attendance
# 0       A     45          60
# 1       B     55          65
# 2       C     60          70
# 3       D     70          75
# 4       E     75          80
# 5       F     85          85
# 6       G     90          90
# 7       H    100          95

# %%
freq=df['Marks'].value_counts()
freq
# Out:
# Marks
# 45     1
# 55     1
# 60     1
# 70     1
# 75     1
# 85     1
# 90     1
# 100    1
# Name: count, dtype: int64

# %%
bins = [0,20,40,60,80,100]
labels=['0-20','21-40','41-60','61-80','81-100']
df['Class Interval'] = pd.cut(df['Marks'],bins=bins,labels=labels)
df
# Out:
#   Student  Marks  Attendance Class Interval
# 0       A     45          60          41-60
# 1       B     55          65          41-60
# 2       C     60          70          41-60
# 3       D     70          75          61-80
# 4       E     75          80          61-80
# 5       F     85          85         81-100
# 6       G     90          90         81-100
# 7       H    100          95         81-100

# %%
grouped_freq = df['Class Interval'].value_counts().sort_index()
grouped_freq
# Out:
# Class Interval
# 0-20      0
# 21-40     0
# 41-60     3
# 61-80     2
# 81-100    3
# Name: count, dtype: int64

# %%
plt.hist(df['Marks'],bins=5)
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.title("Histogram of Marks")
plt.show()

# %%
plt.scatter(df['Attendance'],df['Marks'])
plt.xlabel('Attendance')
plt.ylabel('Marks')
plt.title('Scatter Plot:Attendance vs Marks')
plt.show()

# %%
correlation = df[['Marks','Attendance']].corr()
correlation
# Out:
#                Marks  Attendance
# Marks       1.000000    0.997567
# Attendance  0.997567    1.000000

# %%
plt.boxplot(df['Marks'])
plt.title('Box plot of Marks')
plt.ylabel('Marks')
plt.show()

# %%
import pandas as pd
import numpy as np

data={
    "Name":['Amit','Neha','Raj','Neha','Pooja'],
    "Age":[25,30,np.nan,30,28],
    "Marks":[85,90,88,90,np.nan]
}
df = pd.DataFrame(data)
df

# data
# Out:
#     Name   Age  Marks
# 0   Amit  25.0   85.0
# 1   Neha  30.0   90.0
# 2    Raj   NaN   88.0
# 3   Neha  30.0   90.0
# 4  Pooja  28.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     4 non-null      float64
#  2   Marks   4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#              Age      Marks
# count   4.000000   4.000000
# mean   28.250000  88.250000
# std     2.362908   2.362908
# min    25.000000  85.000000
# 25%    27.250000  87.250000
# 50%    29.000000  89.000000
# 75%    30.000000  90.000000
# max    30.000000  90.000000

# %%
df.isnull()
# Out:
#     Name    Age  Marks
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False  False  False
# 4  False  False   True

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      1
# Marks    1
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.00
# 1    30.00
# 2    28.25
# 3    30.00
# 4    28.00
# Name: Age, dtype: float64

# %%
df['Marks'].fillna(df['Marks'].mean())
# Out:
# 0    85.00
# 1    90.00
# 2    88.00
# 3    90.00
# 4    88.25
# Name: Marks, dtype: float64

# %%
df
# Out:
#     Name    Age  Marks
# 0   Amit  25.00  85.00
# 1   Neha  30.00  90.00
# 2    Raj  28.25  88.00
# 3   Neha  30.00  90.00
# 4  Pooja  28.00  88.25

# %%
df.isnull().sum()
# Out:
# Name     0
# Age      0
# Marks    0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#     Name    Age  Marks
# 0   Amit  25.00  85.00
# 1   Neha  30.00  90.00
# 2    Raj  28.25  88.00
# 3   Neha  30.00  90.00
# 4  Pooja  28.00  88.25

# %%
import pandas as pd
data={
    'Student':['A','B','C','A','D','B','E'],
    'Marks':[45,55,60,45,70,55,80],
    'Attendance':[60,65,70,60,75,65,85]
}

df=pd.DataFrame(data)
df
# Out:
#   Student  Marks  Attendance
# 0       A     45          60
# 1       B     55          65
# 2       C     60          70
# 3       A     45          60
# 4       D     70          75
# 5       B     55          65
# 6       E     80          85

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
df.duplicated(subset=['Student'])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates
# Out:
#   Student  Marks  Attendance
# 0       A     45          60
# 1       B     55          65
# 2       C     60          70
# 4       D     70          75
# 6       E     80          85

# %%
df_unique_students=df.drop_duplicates(subset=['Student'])
df_unique_students
# Out:
#   Student  Marks  Attendance
# 0       A     45          60
# 1       B     55          65
# 2       C     60          70
# 4       D     70          75
# 6       E     80          85

# %%
df_last = df.drop_duplicates(subset=['Student'],keep='last')

df_last
# Out:
#   Student  Marks  Attendance
# 2       C     60          70
# 3       A     45          60
# 4       D     70          75
# 5       B     55          65
# 6       E     80          85

# %%
df_no_any_duplicates = df.drop_duplicates(subset=['Student'],keep=False)
df_no_any_duplicates
# Out:
#   Student  Marks  Attendance
# 2       C     60          70
# 4       D     70          75
# 6       E     80          85

# %%
df_avg=df.groupby('Student',as_index=False).mean()
df_avg
# Out:
#   Student  Marks  Attendance
# 0       A   45.0        60.0
# 1       B   55.0        65.0
# 2       C   60.0        70.0
# 3       D   70.0        75.0
# 4       E   80.0        85.0

# %%
df['Student'].value_counts()
# Out:
# Student
# A    2
# B    2
# C    1
# D    1
# E    1
# Name: count, dtype: int64

# %%
data={
'Student':['A','B','C','D','E'],
'Marks':[45,55,60,70,90],
'Attendance':[60,65,70,80,95]
}
df=pd.DataFrame(data)
df
# Out:
#   Student  Marks  Attendance
# 0       A     45          60
# 1       B     55          65
# 2       C     60          70
# 3       D     70          80
# 4       E     90          95

# %%
df_norm = df.copy()
df_norm['Marks']=(df['Marks']-df['Marks'].min())/(df['Marks'].max()-df['Marks'].min())
df_norm
# Out:
#   Student     Marks  Attendance
# 0       A  0.000000          60
# 1       B  0.222222          65
# 2       C  0.333333          70
# 3       D  0.555556          80
# 4       E  1.000000          95

# %%
df_std = df['Marks']-df['Marks'].mean()/df['Marks'].std()
df_std
# Out:
# 0    41.257886
# 1    51.257886
# 2    56.257886
# 3    66.257886
# 4    86.257886
# Name: Marks, dtype: float64

# %%
cols = ['Marks','Attendance']

df[cols] = (df[cols]-df[cols].mean())/(df[cols].max()-df[cols].min())
df
# Out:
#   Student     Marks  Attendance
# 0       A -0.422222   -0.400000
# 1       B -0.200000   -0.257143
# 2       C -0.088889   -0.114286
# 3       D  0.133333    0.171429
# 4       E  0.577778    0.600000

# %%
import numpy as np
import pandas as pd

data={
    'Marks':[45,55,60,70,75,85,90,100]
}
df=pd.DataFrame(data)
df
# Out:
#    Marks
# 0     45
# 1     55
# 2     60
# 3     70
# 4     75
# 5     85
# 6     90
# 7    100

# %%
mean_value = df['Marks'].mean()
mean_value
# Out:
# np.float64(72.5)

# %%
med_value=df['Marks'].median()
med_value
# Out:
# 72.5

# %%
mod_value=df['Marks'].mode()
mod_value
# Out:
# 0     45
# 1     55
# 2     60
# 3     70
# 4     75
# 5     85
# 6     90
# 7    100
# Name: Marks, dtype: int64

# %%
var_value = df['Marks'].var()
var_value
# Out:
# 350.0

# %%
std_value=df['Marks'].std()
std_value
# Out:
# 18.708286933869708

# %%
import numpy as np
import pandas as pd

data={
    'Marks':[45,55,60,70,75,85,90,100],
    'Hours_Studied':[2,3,4,5,6,7,8,9]
}
df=pd.DataFrame(data)
df
# Out:
#    Marks  Hours_Studied
# 0     45              2
# 1     55              3
# 2     60              4
# 3     70              5
# 4     75              6
# 5     85              7
# 6     90              8
# 7    100              9

# %%
cov = df.cov()
cov
# Out:
#                     Marks  Hours_Studied
# Marks          350.000000      45.714286
# Hours_Studied   45.714286       6.000000

# %%
cov_marks=df['Marks'].cov(df['Hours_Studied'])
cov_marks
# Out:
# np.float64(45.71428571428571)

# %%
mean_marks=df['Marks'].mean()
mean_marks
# Out:
# np.float64(72.5)

# %%
cor = df.corr()
cor
# Out:
#                   Marks  Hours_Studied
# Marks          1.000000       0.997567
# Hours_Studied  0.997567       1.000000

# %%
cor_marks = df['Marks'].corr(df['Hours_Studied'])
cor_marks
# Out:
# np.float64(0.9975674982216793)

# %%
np.cov(df['Marks'],df['Hours_Studied'])
# Out:
# array([[350.        ,  45.71428571],
#        [ 45.71428571,   6.        ]])

# %%
np.corrcoef(df['Marks'],df['Hours_Studied'])
# Out:
# array([[1.       , 0.9975675],
#        [0.9975675, 1.       ]])

# %%
import pandas as pd
data = {
'Student': ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'],
 'Subject': ['Math', 'Math', 'Science', 'Science', 'Math', 'Science', 'Math', 'Science'],
 'Marks': [78, 85, 62, 70, 90, 88, 75, 80],
 'Hours_Studied': [5, 6, 4, 5, 7, 6, 5, 6]
 }
df=pd.DataFrame(data)
df
# Out:
#   Student  Subject  Marks  Hours_Studied
# 0       A     Math     78              5
# 1       B     Math     85              6
# 2       C  Science     62              4
# 3       D  Science     70              5
# 4       E     Math     90              7
# 5       F  Science     88              6
# 6       G     Math     75              5
# 7       H  Science     80              6

# %%
df.describe()
# Out:
#           Marks  Hours_Studied
# count   8.00000        8.00000
# mean   78.50000        5.50000
# std     9.44155        0.92582
# min    62.00000        4.00000
# 25%    73.75000        5.00000
# 50%    79.00000        5.50000
# 75%    85.75000        6.00000
# max    90.00000        7.00000

# %%
df.groupby('Subject')['Marks'].mean()
# Out:
# Subject
# Math       82.0
# Science    75.0
# Name: Marks, dtype: float64

# %%
df.groupby('Subject')['Marks'].agg(['mean','min','max','count'])
# Out:
#          mean  min  max  count
# Subject
# Math     82.0   75   90      4
# Science  75.0   62   88      4

# %%
df.groupby(['Subject','Hours_Studied'])['Marks'].mean()
# Out:
# Subject  Hours_Studied
# Math     5                76.5
#          6                85.0
#          7                90.0
# Science  4                62.0
#          5                70.0
#          6                84.0
# Name: Marks, dtype: float64

# %%
df['Marks_per_Hour']=df['Marks']/df['Hours_Studied']

df.groupby('Subject')['Marks_per_Hour'].mean()
# Out:
# Subject
# Math       14.405952
# Science    14.375000
# Name: Marks_per_Hour, dtype: float64

# %%
df.groupby('Subject').agg(
    Avg_Marks=('Marks','mean'),
    Max_Marks=('Marks','max'),
    Avg_Hours=('Hours_Studied','mean')
)
# Out:
#          Avg_Marks  Max_Marks  Avg_Hours
# Subject
# Math          82.0         90       5.75
# Science       75.0         88       5.25

# %%
summary=df.groupby('Subject')['Marks'].mean().reset_index()
summary
# Out:
#    Subject  Marks
# 0     Math   82.0
# 1  Science   75.0

# %%
df.reset_index()
# Out:
#    index Student  Subject  Marks  Hours_Studied  Marks_per_Hour
# 0      0       A     Math     78              5       15.600000
# 1      1       B     Math     85              6       14.166667
# 2      2       C  Science     62              4       15.500000
# 3      3       D  Science     70              5       14.000000
# 4      4       E     Math     90              7       12.857143
# 5      5       F  Science     88              6       14.666667
# 6      6       G     Math     75              5       15.000000
# 7      7       H  Science     80              6       13.333333

# %%
import pandas as pd
data = {
 'Student_ID': ['S001','S002','S003','S004','S005'],
 'Gender': ['Male','Female','Male','Female','Male'],
 'Age': [20,21,20,22,21],
 'Marks': [85,90,78,75,85],
 'Subject': ['Math','Science','Math','English','Science']
 }
df = pd.DataFrame(data)
df
# Out:
#   Student_ID  Gender  Age  Marks  Subject
# 0       S001    Male   20     85     Math
# 1       S002  Female   21     90  Science
# 2       S003    Male   20     78     Math
# 3       S004  Female   22     75  English
# 4       S005    Male   21     85  Science

# %%
df.shape
# Out:
# (5, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  5 non-null      object
#  1   Gender      5 non-null      object
#  2   Age         5 non-null      int64
#  3   Marks       5 non-null      int64
#  4   Subject     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 332.0+ bytes

# %%
df.describe()
# Out:
#             Age      Marks
# count   5.00000   5.000000
# mean   20.80000  82.600000
# std     0.83666   6.024948
# min    20.00000  75.000000
# 25%    20.00000  78.000000
# 50%    21.00000  85.000000
# 75%    21.00000  85.000000
# max    22.00000  90.000000

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3
# Female    2
# Name: count, dtype: int64

# %%
df.groupby('Subject')['Marks'].mean()
# Out:
# Subject
# English    75.0
# Math       81.5
# Science    87.5
# Name: Marks, dtype: float64

# %%
df.groupby('Gender')['Marks'].mean()
# Out:
# Gender
# Female    82.500000
# Male      82.666667
# Name: Marks, dtype: float64

# %%
df.groupby('Subject')['Marks'].agg(['mean','min','max','std'])
# Out:
#          mean  min  max       std
# Subject
# English  75.0   75   75       NaN
# Math     81.5   78   85  4.949747
# Science  87.5   85   90  3.535534

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = {
 'Student_ID': ['S001','S002','S003','S004','S005','S006','S006'],
 'Gender': ['Male','Female','Male','Female','Male','Female','Female'],
 'Age': [20,21,20,22,21,23,23],
 'Marks': [85,90,np.nan,75,85,88,88],
 'Attendance': [90,95,85,80,90,92,92],
 'Subject': ['Math','Science','Math','English','Science','Math','Math']
}
df=pd.DataFrame(data)
df
# Out:
#   Student_ID  Gender  Age  Marks  Attendance  Subject
# 0       S001    Male   20   85.0          90     Math
# 1       S002  Female   21   90.0          95  Science
# 2       S003    Male   20    NaN          85     Math
# 3       S004  Female   22   75.0          80  English
# 4       S005    Male   21   85.0          90  Science
# 5       S006  Female   23   88.0          92     Math
# 6       S006  Female   23   88.0          92     Math

# %%
df.head()
# Out:
#   Student_ID  Gender  Age  Marks  Attendance  Subject
# 0       S001    Male   20   85.0          90     Math
# 1       S002  Female   21   90.0          95  Science
# 2       S003    Male   20    NaN          85     Math
# 3       S004  Female   22   75.0          80  English
# 4       S005    Male   21   85.0          90  Science

# %%
df.shape
# Out:
# (7, 6)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of   Student_ID  Gender  Age  Marks  Attendance  Subject
# 0       S001    Male   20   85.0          90     Math
# 1       S002  Female   21   90.0          95  Science
# 2       S003    Male   20    NaN          85     Math
# 3       S004  Female   22   75.0          80  English
# 4       S005    Male   21   85.0          90  Science
# 5       S006  Female   23   88.0          92     Math
# 6       S006  Female   23   88.0          92     Math>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  7 non-null      object
#  1   Gender      7 non-null      object
#  2   Age         7 non-null      int64
#  3   Marks       6 non-null      float64
#  4   Attendance  7 non-null      int64
#  5   Subject     7 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 468.0+ bytes

# %%
df.isnull().sum()
# Out:
# Student_ID    0
# Gender        0
# Age           0
# Marks         1
# Attendance    0
# Subject       0
# dtype: int64

# %%
df['Marks'].fillna(df['Marks'].mean())
# Out:
# 0    85.000000
# 1    90.000000
# 2    85.166667
# 3    75.000000
# 4    85.000000
# 5    88.000000
# 6    88.000000
# Name: Marks, dtype: float64

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#   Student_ID  Gender  Age      Marks  Attendance  Subject
# 0       S001    Male   20  85.000000          90     Math
# 1       S002  Female   21  90.000000          95  Science
# 2       S003    Male   20  85.166667          85     Math
# 3       S004  Female   22  75.000000          80  English
# 4       S005    Male   21  85.000000          90  Science
# 5       S006  Female   23  88.000000          92     Math

# %%
norm_marks = (df['Marks']-df['Marks'].min())/(df['Marks'].max()-df['Marks'].min())
norm_marks
# Out:
# 0    0.666667
# 1    1.000000
# 2    0.677778
# 3    0.000000
# 4    0.666667
# 5    0.866667
# Name: Marks, dtype: float64

# %%
df
# Out:
#   Student_ID  Gender  Age      Marks  Attendance  Subject
# 0       S001    Male   20  85.000000          90     Math
# 1       S002  Female   21  90.000000          95  Science
# 2       S003    Male   20  85.166667          85     Math
# 3       S004  Female   22  75.000000          80  English
# 4       S005    Male   21  85.000000          90  Science
# 5       S006  Female   23  88.000000          92     Math

# %%
df['Marks'].mean()
# Out:
# np.float64(84.69444444444444)

# %%
df['Marks'].median()
# Out:
# 85.08333333333334

# %%
df['Marks'].mode()
# Out:
# 0    85.0
# Name: Marks, dtype: float64

# %%
df['Marks'].var()
# Out:
# 26.693518518518516

# %%
df['Marks'].std()
# Out:
# 5.166577060154868

# %%
df['Subject'].value_counts()
# Out:
# Subject
# Math       3
# Science    2
# English    1
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      3
# Female    3
# Name: count, dtype: int64

# %%
plt.hist(df['Marks'],bins=5,edgecolor='black')
plt.title('Marks Distribution')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(df['Attendance'],df['Marks'])
plt.xlabel('Attendance')
plt.ylabel('Marks')
plt.title('Attendance vs Marks')
plt.show()

# %%
plt.boxplot(df['Marks'])
plt.title('Boxplot of Marks')
plt.ylabel('Marks')
plt.show()

# %%
df[['Marks','Attendance']].corr()
# Out:
#                Marks  Attendance
# Marks       1.000000    0.923432
# Attendance  0.923432    1.000000

# %%
df[['Marks','Attendance']].cov()
# Out:
#                 Marks  Attendance
# Marks       26.693519   25.544444
# Attendance  25.544444   28.666667

# %%
df.groupby('Subject')['Marks'].mean()
# Out:
# Subject
# English    75.000000
# Math       86.055556
# Science    87.500000
# Name: Marks, dtype: float64

# %%
df.groupby('Gender')['Attendance'].mean()
# Out:
# Gender
# Female    89.000000
# Male      88.333333
# Name: Attendance, dtype: float64
